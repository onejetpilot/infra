# %% [markdown]
# # Продвинутый курс SQL
#
# Учебная база: PostgreSQL 17, датасет Olist.
# Всего: **120 практических заданий**.

# %% [markdown]
# ## Программа
#
# 1. [Функции PostgreSQL — 30 заданий](01_Functions_30_Tasks.ipynb) — готово.
# 2. Хранимые процедуры — 30 заданий.
# 3. Дедупликация данных — 30 заданий.
# 4. Транзакции и уровни изоляции — 30 заданий.
#
# В каждом блоке задания идут от простых к сложным. Исходные таблицы `raw`, `staging` и `mart` не изменяются: практические объекты создаются в отдельной схеме `training`.

# %%
# %load_ext sql
# %sql postgresql+psycopg2://student:sqltrain2026@sql-train-db:5432/sql_train

# %%
# %%sql
# SELECT
#     current_database() AS database,
#     current_user AS user_name,
#     version() AS postgres_version;

# %%
# %%sql
# SELECT
#     (SELECT count(*) FROM raw.orders) AS orders,
#     (SELECT count(*) FROM raw.order_items) AS order_items,
#     (SELECT count(*) FROM raw.customers) AS customers,
#     (SELECT count(*) FROM raw.products) AS products;

# %% [markdown]
# ## Статус подготовки
#
# Подключение и учебная база готовы. Блок функций и его автоматические проверки готовы. Решения не публикуются; остальные три блока добавляются поэтапно.
